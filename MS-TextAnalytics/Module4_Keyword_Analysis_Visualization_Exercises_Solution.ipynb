# %% [markdown]
# # Text Analytics | BAIS:6100
# # Module 4: Keyword Analysis and Visualization - Exercises

# %% [markdown]
# Instructor: Kang-Pyo Lee

# %% [markdown]
# ## Exercises - Keyword Analysis and Visualization

# %% [markdown]
# Twitter hashtag options:
# - ai
# - bitcoin
# - blacklivesmatter
# - bts
# - covid19
# - fakenews
# - innovation
# - mentalhealth
# - metoo
# - startup

# %% [markdown]
# Choose a Twitter hashtag you're interested in and save it in the `hashtag` variable below.

# %%
hashtag = "mentalhealth"

# %%
import pandas as pd
pd.set_option('display.max_colwidth', 150)

months = ["202012", "202011", "202010", "202009", "202008", "202007", 
          "202006", "202005", "202004", "202003", "202002", "202001"]

N = 1000

df = pd.DataFrame()
for month in months:
    dftmp = pd.read_csv("classdata/tweets/tweets_{}_{}.csv".format(hashtag, month), sep="\t", quoting=3)
    
    ##############################################
    # Create a random sample of n rows.
    ##############################################
    if len(dftmp) > N:
        dftmp = dftmp.sample(n=N)
    ##############################################
    
    df = pd.concat([df, dftmp])
    print("{}: {:,}".format(month, len(dftmp)))

print("Total number of tweets in df: {:,}\n".format(len(df)))

df.user_name = df.user_name.astype(str)
df.text = df.text.astype(str)

df
# Out:
# 202012: 1,000
# 202011: 1,000
# 202010: 1,000
# 202009: 1,000
# 202008: 1,000
# 202007: 1,000
# 202006: 1,000
# 202005: 1,000
# 202004: 1,000
# 202003: 1,000
# 202002: 1,000
# 202001: 1,000
# Total number of tweets in df: 12,000
#                           created_at user_screen_name              user_name  \
# 3456  Sat Dec 12 07:43:27 +0000 2020  StTeresaNursery   St. Teresa’s Nursery
# 4337  Tue Dec 08 02:18:35 +0000 2020  leslieasheppard  leslie sheppard 🌎⚙️📈🎼
# 1855  Mon Dec 21 02:42:16 +0000 2020      yoongichxck      jean⁷ | STREAM BE
# 2757  Tue Dec 15 23:02:35 +0000 2020    DeniseCharles         denise charles
# 2795  Wed Dec 16 03:51:56 +0000 2020  MentalHealthBo5      Mental Health Bot
# ...                              ...              ...                    ...
# 4146  Thu Jan 23 22:42:24 +0000 2020  Lauren_Langbein        Lauren Langbein
# 7132  Sat Jan 11 00:51:20 +0000 2020      chiefcoutts           Jamie Coutts
# 7769  Wed Jan 08 09:57:16 +0000 2020       tschitchat        House of LilitH
# 2579  Wed Jan 29 14:33:46 +0000 2020   VaughanChamber        Vaughan Chamber
# 6666  Mon Jan 13 20:16:37 +0000 2020  ScissorSyndrome                  Julie
#
#                                                                                                                                                   text
# 3456                                                                      RT @DrChrisMooreEP: 5 simple steps to safeguard #wellbeing and #mentalhealth
# 4337      RT @SickKidsNews: In the spring, SickKids brought together 4 leading child #mentalhealth research teams to study impacts of the #COVID19 pa…
# 1855        RT @r0okClothing: 💜 Support Mental Health In Style! 💜#breakingnews #mentalhealthmatters #mentalhealth #mentalhealthawareness #suicideprev…
# 2757      RT @Hafal_: We recently launched a fantastic new out-of-hours Sanctuary service for people at risk of a #mentalhealth crisis in #Swansea an…
# 2795       RT @DrAimeeGrant: I was shocked to learn that in Cardiff a GP's referral for you to *have the #MentalHealth crisis team phone number* (not…
# ...                                                                                                                                                ...
# 4146        RT @ResearchAtJeff: Now, it's YOUR turn.What do you think we can do to support the #mentalhealth of researchers? Share your thoughts belo…
# 7132          RT @ACSheldonYoung: It was an important day here @VanFireRescue First day of training with our of #MentalHealth team!The work that this…
# 7769  #MentalHealth is part of the health condition, sometimes exercise, eating well &amp; counselling isn't enough, it's imp… https://t.co/civIi081XW
# 2579      #MentalHealth is everyone's business. Remember that Every Action Counts - let's work together to end the stigma and… https://t.co/NARAfV0y1j
# 6666      RT @lilyjoproject: Thank you wearetearfund for working with me on this short film about #mentalhealth - I hope it’s helpful to you ✨ Find t…
#
# [12000 rows x 4 columns]

# %% [markdown]
# 1\. Import the following modules:
# - Counter from collections
# - gender_guesser.detector as gender
# - Image from IPython.display
# - nltk
# - string
# - TextBlob from textblob
# - WordCloud from wordcloud

# %%
# Your answer here
from collections import Counter
import gender_guesser.detector as gender
from IPython.display import Image
import nltk
import string
from textblob import TextBlob
from wordcloud import WordCloud

# %% [markdown]
# 2\. Add two new columns `tagged_words` and `polarity` to `df`.

# %%
# Your answer here
df["words"] = df.text.apply(lambda x: nltk.word_tokenize(x))
df["tagged_words"] = df.words.apply(lambda x: nltk.pos_tag(x))
df["polarity"] = df.text.apply(lambda x: TextBlob(x).sentiment.polarity)

# %%
# Check your answer here. (Do not make any change to this cell. Just run this cell.)
df[["text", "tagged_words", "polarity"]]
# Out:
#                                                                                                                                                   text  \
# 3456                                                                      RT @DrChrisMooreEP: 5 simple steps to safeguard #wellbeing and #mentalhealth
# 4337      RT @SickKidsNews: In the spring, SickKids brought together 4 leading child #mentalhealth research teams to study impacts of the #COVID19 pa…
# 1855        RT @r0okClothing: 💜 Support Mental Health In Style! 💜#breakingnews #mentalhealthmatters #mentalhealth #mentalhealthawareness #suicideprev…
# 2757      RT @Hafal_: We recently launched a fantastic new out-of-hours Sanctuary service for people at risk of a #mentalhealth crisis in #Swansea an…
# 2795       RT @DrAimeeGrant: I was shocked to learn that in Cardiff a GP's referral for you to *have the #MentalHealth crisis team phone number* (not…
# ...                                                                                                                                                ...
# 4146        RT @ResearchAtJeff: Now, it's YOUR turn.What do you think we can do to support the #mentalhealth of researchers? Share your thoughts belo…
# 7132          RT @ACSheldonYoung: It was an important day here @VanFireRescue First day of training with our of #MentalHealth team!The work that this…
# 7769  #MentalHealth is part of the health condition, sometimes exercise, eating well &amp; counselling isn't enough, it's imp… https://t.co/civIi081XW
# 2579      #MentalHealth is everyone's business. Remember that Every Action Counts - let's work together to end the stigma and… https://t.co/NARAfV0y1j
# 6666      RT @lilyjoproject: Thank you wearetearfund for working with me on this short film about #mentalhealth - I hope it’s helpful to you ✨ Find t…
#
#                                                                                                                                                tagged_words  \
# 3456  [(RT, NNP), (@, JJ), (DrChrisMooreEP, NNP), (:, :), (5, CD), (simple, JJ), (steps, NNS), (to, TO), (safeguard, VB), (#, #), (wellbeing, VBG), (and...
# 4337  [(RT, NNP), (@, NNP), (SickKidsNews, NNP), (:, :), (In, IN), (the, DT), (spring, NN), (,, ,), (SickKids, NNP), (brought, VBD), (together, RB), (4,...
# 1855  [(RT, NNP), (@, NNP), (r0okClothing, NN), (:, :), (💜, JJ), (Support, NNP), (Mental, NNP), (Health, NNP), (In, IN), (Style, NNP), (!, .), (💜, NN), ...
# 2757  [(RT, NNP), (@, NNP), (Hafal_, NNP), (:, :), (We, PRP), (recently, RB), (launched, VBD), (a, DT), (fantastic, JJ), (new, JJ), (out-of-hours, JJ), ...
# 2795  [(RT, NNP), (@, NNP), (DrAimeeGrant, NNP), (:, :), (I, PRP), (was, VBD), (shocked, VBN), (to, TO), (learn, VB), (that, IN), (in, IN), (Cardiff, NN...
# ...                                                                                                                                                     ...
# 4146  [(RT, NNP), (@, NNP), (ResearchAtJeff, NNP), (:, :), (Now, RB), (,, ,), (it, PRP), ('s, VBZ), (YOUR, NNP), (turn.What, RB), (do, VBP), (you, PRP),...
# 7132  [(RT, NNP), (@, NNP), (ACSheldonYoung, NNP), (:, :), (It, PRP), (was, VBD), (an, DT), (important, JJ), (day, NN), (here, RB), (@, NNP), (VanFireRe...
# 7769  [(#, #), (MentalHealth, NNP), (is, VBZ), (part, NN), (of, IN), (the, DT), (health, NN), (condition, NN), (,, ,), (sometimes, RB), (exercise, NN), ...
# 2579  [(#, #), (MentalHealth, NNP), (is, VBZ), (everyone, NN), ('s, POS), (business, NN), (., .), (Remember, NNP), (that, IN), (Every, NNP), (Action, NN...
# 6666  [(RT, NNP), (@, NNP), (lilyjoproject, NN), (:, :), (Thank, NN), (you, PRP), (wearetearfund, VBP), (for, IN), (working, VBG), (with, IN), (me, PRP)...
#
#       polarity
# 3456  0.000000
# 4337  0.000000
# 1855 -0.125000
# 2757  0.178788
# 2795 -0.700000
# ...        ...
# 4146  0.000000
# 7132  0.325000
# 7769  0.000000
# 2579  0.100000
# 6666  0.000000
#
# [12000 rows x 3 columns]

# %% [markdown]
# 3\. List the top-50 most common words in the `text` column along with their frequencies, considering only the global English stopwords. You may reuse the `get_counter` function you have used before.

# %%
# Your answer here
def get_counter(dataframe, stopwords=[], target_tag=None):
    counter = Counter()
    
    for l in dataframe.tagged_words:
        word_set = set()

        for t in l:
            word = t[0].lower()
            tag = t[1]

            ##########################################################
            # Check if the word is a stopword.
            ##########################################################
            if word in stopwords:
                continue

            if target_tag is None:
                word_set.add(word)
            else:
                ##########################################################
                # Check the tag
                ##########################################################
                if tag.startswith(target_tag):
                    word_set.add(word)
                else:
                    continue

        counter.update(word_set)
        
    return counter

global_stopwords = nltk.corpus.stopwords.words("english") 
counter1 = get_counter(df, global_stopwords)
counter1.most_common(50)
# Out:
# [('#', 11998),
#  (':', 11392),
#  ('mentalhealth', 11299),
#  ('@', 8649),
#  ('rt', 7398),
#  ('https', 5091),
#  ('.', 3818),
#  (',', 3188),
#  ('health', 1870),
#  ('!', 1775),
#  ('mental', 1417),
#  (';', 1155),
#  ('’', 1149),
#  ('&', 1082),
#  ('amp', 1038),
#  ("'s", 997),
#  ('?', 882),
#  ('people', 755),
#  ('covid19', 718),
#  ('-', 586),
#  ('help', 505),
#  ('today', 499),
#  ('support', 493),
#  ('important', 490),
#  ('mentalhealth…', 478),
#  ('new', 473),
#  ('us', 439),
#  ('…', 416),
#  ('pandemic', 412),
#  ('need', 401),
#  ('time', 399),
#  ('latest', 397),
#  ('anxiety', 376),
#  ('love', 364),
#  ('wellbeing', 363),
#  ('thanks', 359),
#  ('depression', 356),
#  ('care', 355),
#  ('``', 349),
#  ('joytrain', 337),
#  ('mindfulness', 331),
#  ('day', 329),
#  ('(', 328),
#  ('joy', 320),
#  ('issues', 314),
#  ('karijoys', 304),
#  ('let', 303),
#  (')', 299),
#  ('coronavirus', 297),
#  ('one', 295)]

# %% [markdown]
# 4\. Examine the 50 most common words from question 3 and define your own local stopwords in a list named `local_stopwords`. Then, list the top-50 most common words and their frequencies, this time considering both the global and local stopwords.

# %%
# Your answer here
local_stopwords = [c for c in string.punctuation] +\
                  ['’', '``', '…', '...', "''", '‘', '“', '”', "'m", "'re", "'s", "'ve", 'amp', 'https', "n't", 'rt', 
                   'a…', 'health', 'mental', 'mentalhealth', 'mentalhealth…', 't…']

counter2 = get_counter(df, global_stopwords+local_stopwords)
counter2.most_common(50)
# Out:
# [('people', 755),
#  ('covid19', 718),
#  ('help', 505),
#  ('today', 499),
#  ('support', 493),
#  ('important', 490),
#  ('new', 473),
#  ('us', 439),
#  ('pandemic', 412),
#  ('need', 401),
#  ('time', 399),
#  ('latest', 397),
#  ('anxiety', 376),
#  ('love', 364),
#  ('wellbeing', 363),
#  ('thanks', 359),
#  ('depression', 356),
#  ('care', 355),
#  ('joytrain', 337),
#  ('mindfulness', 331),
#  ('day', 329),
#  ('joy', 320),
#  ('issues', 314),
#  ('karijoys', 304),
#  ('let', 303),
#  ('coronavirus', 297),
#  ('one', 295),
#  ('take', 287),
#  ('join', 286),
#  ('talk', 284),
#  ('know', 273),
#  ('impact', 273),
#  ('great', 257),
#  ('good', 255),
#  ('daily', 242),
#  ('services', 241),
#  ('crisis', 237),
#  ('children', 234),
#  ('world', 232),
#  ('many', 230),
#  ('young', 228),
#  ('get', 228),
#  ('please', 226),
#  ('check', 226),
#  ('life', 223),
#  ('mentalhealthawareness', 222),
#  ('physical', 221),
#  ('work', 213),
#  ('free', 211),
#  ('look', 207)]

# %% [markdown]
# 5\. Draw a word cloud that visualizes the top-100 most common words. You may reuse the `draw_wordcloud` function you have used before.

# %%
# Your answer here
def draw_wordcloud(counter, image_file_name, max_words=100):
    wc = WordCloud(background_color="white", max_words=max_words, width=800, height=500)
    wc.generate_from_frequencies(counter)
    wc.to_file(image_file_name)
    display(Image(filename=image_file_name))
    
draw_wordcloud(counter2, "outcome/ex_wordcloud2.png", 100)

# %% [markdown]
# 6\. Select from `df` the rows with the polarity score larger than or equal to 0.7, i.e., strongly positive tweets. List the top-50 most common words in the selected text along with their frequencies, reusing the global and local stopwords defined earlier.

# %%
# Your answer here
dftmp = df[df.polarity >= 0.7]
counter3 = get_counter(dftmp, global_stopwords+local_stopwords)
counter3.most_common(50)
# Out:
# [('great', 105),
#  ('joytrain', 103),
#  ('happy', 98),
#  ('joy', 97),
#  ('karijoys', 97),
#  ('mindfulness', 87),
#  ('good', 83),
#  ('love', 64),
#  ('quote', 64),
#  ('beautiful', 61),
#  ('best', 50),
#  ('iam', 50),
#  ('goldenhearts', 49),
#  ('kindness', 48),
#  ('proud', 32),
#  ('day', 30),
#  ('people', 24),
#  ('time', 21),
#  ('covid19', 21),
#  ('today', 20),
#  ('way', 20),
#  ('week', 19),
#  ('world', 18),
#  ('..', 18),
#  ('iqrtg', 18),
#  ('chooselove', 17),
#  ('talk', 17),
#  ('peace', 16),
#  ('mentalhealthawareness', 16),
#  ('wellbeing', 16),
#  ('happiness', 16),
#  ('morning', 16),
#  ('successtrain', 15),
#  ('help', 15),
#  ('thank', 15),
#  ('excellent', 15),
#  ('work', 15),
#  ('see', 15),
#  ('via', 15),
#  ('gratitude', 14),
#  ('wonderful', 14),
#  ('heart', 14),
#  ('let', 14),
#  ('perfect', 14),
#  ('welcome', 13),
#  ('loved', 13),
#  ('depression', 13),
#  ('everyone', 13),
#  ('hope', 12),
#  ('thankful', 12)]

# %% [markdown]
# 7\. Draw a word cloud that visualizes the top-100 most common words in the positive tweets.

# %%
# Your answer here
draw_wordcloud(counter3, "outcome/ex_wordcloud3.png", 100)

# %% [markdown]
# 8\. Select from `df` the rows with the polarity score larger than or equal to 0.7, i.e., strongly positive tweets. List the top-50 most common <b>adjectives</b> in the selected text along with their frequencies, reusing the global and local stopwords defined earlier.

# %%
# Your answer here
dftmp = df[df.polarity >= 0.7]
counter4 = get_counter(dftmp, global_stopwords+local_stopwords, "JJ")
counter4.most_common(50)
# Out:
# [('happy', 96),
#  ('good', 78),
#  ('great', 78),
#  ('best', 44),
#  ('beautiful', 42),
#  ('proud', 21),
#  ('wonderful', 14),
#  ('excellent', 14),
#  ('perfect', 12),
#  ('brilliant', 11),
#  ('spdc', 10),
#  ('thankful', 9),
#  ('incredible', 9),
#  ('wellness', 6),
#  ('loved', 6),
#  ('selfcare', 6),
#  ('mentalhealthawareness', 6),
#  ('amazing', 6),
#  ('latest', 5),
#  ('happiness', 4),
#  ('virtual', 4),
#  ('lockdown', 4),
#  ('grateful', 3),
#  ('awesome', 3),
#  ('mentalhealthmatters…', 3),
#  ('mentalillness', 3),
#  ('welcome', 3),
#  ('selflove', 3),
#  ('darkest', 3),
#  ('mindfulness', 3),
#  ('superb', 3),
#  ('👌🏻', 3),
#  ('arttherapy', 3),
#  ('many', 3),
#  ('//t.co/x7w2jfq0fn', 2),
#  ('😴', 2),
#  ('primary', 2),
#  ('community-based', 2),
#  ('😊', 2),
#  ('upcoming', 2),
#  ('stress', 2),
#  ('suffolk', 2),
#  ('fascinating', 2),
#  ('expressive', 2),
#  ('awareness', 2),
#  ('finnish', 2),
#  ('perinatal', 2),
#  ('to…', 2),
#  ('//t.co/x7w2jfypnp', 2),
#  ('lived', 2)]

# %% [markdown]
# 9\. Draw a word cloud that visualizes the top-100 most common adjectives in the positive tweets.

# %%
# Your answer here
draw_wordcloud(counter4, "outcome/ex_wordcloud4.png", 100)
